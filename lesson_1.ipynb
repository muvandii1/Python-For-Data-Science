# %% [markdown]
# <a href="https://colab.research.google.com/github/muvandii1/Python-For-Data-Science/blob/main/lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 📘 **Section 1: Loading Data with Pandas**
#
# #### 🔹 Basics
#
# * **Pandas** = Python library for data analysis.
# * Main structures: `Series` (1D), `DataFrame` (2D).
#
# #### 🔹 Load Data
#
# ```python
# pd.read_csv('file.csv')       # CSV
# pd.read_excel('file.xlsx')    # Excel
# pd.read_json('file.json')     # JSON
# ```
#
# * Load from URL: `pd.read_csv('https://...')`
# * Common options: `sep`, `header`, `names`, `index_col`
#
# #### 🔹 Quick View
#
# ```python
# df.head(), df.tail(), df.shape
# df.columns, df.info(), df.describe()
# ```
#
# #### 🔹 Tips
#
# * Use `df.dtypes` for data types.
# * Handle missing: `na_values` param.
#
# ---

# %%
import pandas as pd
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jayaantanaath/student-habits-vs-academic-performance")

df = pd.read_csv(f'{path}/student_habits_performance.csv')
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
path2 = kagglehub.dataset_download('sunilthite/text-document-classification-dataset')
print(path)
# Out:
# /kaggle/input/student-habits-vs-academic-performance

# %%
# !ls {path2}
# Out:
# df_file.csv

# %%
text_file = pd.read_csv(f'{path2}/df_file.csv')
text_file.head()
# Out:
#                                                 Text  Label
# 0  Budget to set scene for election\n \n Gordon B...      0
# 1  Army chiefs in regiments decision\n \n Militar...      0
# 2  Howard denies split over ID cards\n \n Michael...      0
# 3  Observers to monitor UK election\n \n Minister...      0
# 4  Kilroy names election seat target\n \n Ex-chat...      0

# %% [markdown]
# Data exploration and Preprocessing
# Questions
#
#
# 🔍 Part 1: Data Exploration (EDA)
#
# Shape and Structure
#
# What is the shape of the dataset?
#
# How many columns and rows are there?

# %%
shape = text_file.shape
no_of_columns = shape[0]
shape, no_of_columns
# Out:
# ((2225, 2), 2225)

# %% [markdown]
# Basic Info
#
# Use .info() and describe what types of data are in the dataset.
#
# Which columns have missing values?

# %%
text_file.info()
print(text_file.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    2225 non-null   object
#  1   Label   2225 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 34.9+ KB
# Text     0
# Label    0
# dtype: int64

# %% [markdown]
# Value Distribution
#
# What are the most common product categories?
#
# How many purchases were made from each country?

# %% [markdown]
# Correlation Analysis
#
# What is the correlation between Age and PurchaseAmount?
#
# Which numeric columns are most strongly related?
